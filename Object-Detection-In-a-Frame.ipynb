# %% [markdown]
# <a href="https://colab.research.google.com/github/rajni0829/Computer-Vision-Prac/blob/main/Object-Detection-In-a-Frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Refer: https://www.youtube.com/watch?v=RFqvTmEFtOE

# %%
# ! pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt

# %%
config_file = '/content/drive/MyDrive/API_Config/ssd_mobilenet_v3_large_coco_2020_01_14.pbtxt'
frozen_model = '/content/drive/MyDrive/API_Config/frozen_inference_graph.pb'

# %%
model = cv2.dnn_DetectionModel(frozen_model,config_file)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: OpenCV(4.1.2) /io/opencv/modules/dnn/src/tensorflow/tf_importer.cpp:577: error: (-2:Unspecified error) Const input blob for weights not found in function 'getConstBlob'
#
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-29-4d856c1e9541> in <module>()
# ----> 1 model = cv2.dnn_DetectionModel(frozen_model,config_file)
#
# SystemError: <class 'cv2.dnn_DetectionModel'> returned a result with an error set

# %%
from ftplib import *

global ftp

classLabels = []
file_name = '/content/drive/MyDrive/API_Config/labels.txt'

with open(file_name,'rt') as fpt:
  classLabels = ftp.read().rstrip('\n').split('\n')

# %%
print(classLabels)

# %%
print(len(classLabels))

# %%
model.setInputSize(320,320)
model.setInputScale(1.0/127.5)
model.setInputSize(127.5, 127.5, 127.5)
model.SetInputSwapRB(True)

# %%
# reading an image
img = cv2.imread('/content/drive/MyDrive/IMG20191027204217.jpg')

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
classIndex, confidece, bbox = model.detect(img.confThreshold=0.8)
# Out:
#   File "<ipython-input-30-00e96cd4bd8a>", line 1
#     classIndex, confidece, bbox = model.detect(img.confThreshold=0.8)
#                                               ^
# SyntaxError: keyword can't be an expression

# %%
print(classIndex)

# %%
font_scale = 3
font = cv2.FONT_HERSHEY_PLAIN
for classInd, conf, boxes in zip(classIndex, confidece.flatten(),bbox):
  cv2.rectangle(img,boxes,(255,0,0),2)
  cv2.putText(img,classLabels[classInd-1],(boxes[0]+10,boxes[1]+40),font,fontScale=font_scale,color=(0,255,0),thickness=3)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
# Checking for Video
cap = cv2.VideoCapture("/content/drive/MyDrive/Dataset_Vdo/Food_chain.mp4")

# check if video is opened correctly
if not cap.isOpened():
  cap = cv2.VideoCapture(0)
if not cap.isOpened():
  raise IOError("Cannot Open The video")

font_scale = 3
font = cv2.FONT_HERSHEY_PLAIN

while True:
  ret, frame = cap.read()

  classIndex,confidece,bbox = model.detect(frame,confThreshold=0.55)
  print(classIndex)

  if(len(classIndex) != 0):
    for classInd, conf, boxes in zip(classIndex.flatten(), confidece.flatten(),bbox):
      if (classInd <= 80):
        cv2.rectangle(img,boxes,(255,0,0),2)
        cv2.putText(frame,classLabels[classInd-1],(boxes[0]+10,boxes[1]+40),font,fontScale=font_scale,color=(0,255,0),thickness=3)

  cv2.imshow("Object Detection",frame)

  if cv2.waitKey(2) & 0xFF == ord('q'):
    break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-ac42a116f6da> in <module>()
#      14   ret, frame = cap.read()
#      15
# ---> 16   classIndex,confidece,bbox = model.detect(frame,confThreshold=0.55)
#      17   print(classIndex)
#      18
#
# NameError: name 'model' is not defined

# %%
# Checking for Webcame
cap = cv2.VideoCapture(1)

# check if Webcam is opened correctly
if not cap.isOpened():
  cap = cv2.VideoCapture(0)
if not cap.isOpened():
  raise IOError("Cannot Open The  Webcam")


font_scale = 3
font = cv2.FONT_HERSHEY_PLAIN

while True:
  ret, frame = cap.read()

  classIndex,confidece,bbox = model.detect(frame,confThreshold=0.55)
  print(classIndex)

  if(len(classIndex) != 0):
    for classInd, conf, boxes in zip(classIndex.flatten(), confidece.flatten(),bbox):
      if (classInd <= 80):
        cv2.rectangle(img,boxes,(255,0,0),2)
        cv2.putText(frame,classLabels[classInd-1],(boxes[0]+10,boxes[1]+40),font,fontScale=font_scale,color=(0,255,0),thickness=3)

  cv2.imshow("Object Detection",frame)

  if cv2.waitKey(2) & 0xFF == ord('q'):
    break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-33-369882954b67> in <module>()
#       6   cap = cv2.VideoCapture(0)
#       7 if not cap.isOpened():
# ----> 8   raise IOError("Cannot Open The  Webcam")
#       9
#      10
#
# OSError: Cannot Open The  Webcam
